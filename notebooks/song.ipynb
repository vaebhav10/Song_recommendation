# %%
import pandas as pd 
import numpy as np 
import pprint

# %%
df = pd.read_csv('dataset.csv')
df.sample(4)
# Out:
#         Unnamed: 0                track_id       artists  \
# 75790        75790  2SIgGbcduNKHTFEFcvmUaS        Deuter
# 18625        18625  14KRQPqBGbMHKheHc31Xdm      Tom Papa
# 102284      102284  4ZRs2BzVlK54h1GyZO799I  Paolo Nutini
# 105529      105529  6tw6f2SpScnkWeFMzc9Ykd     Beat Oven
#
#                           album_name                 track_name  popularity  \
# 75790   Koyasan: Reiki Sound Healing  Sound of Invisible Waters          50
# 18625                     Human Mule           Saving the World          21
# 102284  Human - Best Adult Pop Tunes                     Numpty           0
# 105529  Kid Tested & Mother Approved                  The Feels          32
#
#         duration_ms  explicit  danceability  energy  ...  loudness  mode  \
# 75790        572853     False         0.111  0.0211  ...   -26.997     0
# 18625        166810     False         0.671  0.5970  ...   -15.384     1
# 102284       234066      True         0.839  0.4410  ...    -9.024     1
# ...

# %%
df.duplicated(subset=["track_id"]).sum()
# Out:
# np.int64(24259)

# %%
df.drop_duplicates(subset= ['track_id'],inplace= True)

# %%
(df.select_dtypes('str')).columns.tolist()
# Out:
# ['track_id', 'artists', 'album_name', 'track_name', 'track_genre']

# %%
df.duplicated(subset=['artists', 'track_name','explicit']).sum()
# Out:
# np.int64(8319)

# %%
df[df.duplicated(subset=['artists', 'track_name','explicit'])].head()
# Out:
#     Unnamed: 0                track_id                               artists  \
# 18          18  2qLMf6TuEC3ruGJg4SMMN6             Jason Mraz;Colbie Caillat
# 20          20  3S0OXQeoh0w6AY8WQVckRW                            Jason Mraz
# 22          22  5TvE3pk05pyFIGdSY9j4DJ  A Great Big World;Christina Aguilera
# 28          28  5QAMZTM5cmLg3fHX9ZbTZi                            Jason Mraz
# 29          29  2qESE1ZeWly7I3YjyTXmXh                            Jason Mraz
#
#                                            album_name         track_name  \
# 18                We Sing. We Dance. We Steal Things.              Lucky
# 20                We Sing. We Dance. We Steal Things.          I'm Yours
# 22  Is There Anybody Out There? - Track by Track C...      Say Something
# 28                                     Christmas Time  Winter Wonderland
# 29                             Perfect Christmas Hits  Winter Wonderland
#
# ...

# %%
df.drop_duplicates(subset=['artists', 'track_name','explicit'],inplace= True )

# %%
df.shape
# Out:
# (81422, 21)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df=df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 81421 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        81421 non-null  int64
#  1   track_id          81421 non-null  str
#  2   artists           81421 non-null  str
#  3   album_name        81421 non-null  str
#  4   track_name        81421 non-null  str
#  5   popularity        81421 non-null  int64
#  6   duration_ms       81421 non-null  int64
#  7   explicit          81421 non-null  bool
#  8   danceability      81421 non-null  float64
#  9   energy            81421 non-null  float64
#  10  key               81421 non-null  int64
#  11  loudness          81421 non-null  float64
#  12  mode              81421 non-null  int64
#  13  speechiness       81421 non-null  float64
#  14  acousticness      81421 non-null  float64
#  15  instrumentalness  81421 non-null  float64
#  16  liveness          81421 non-null  float64
# ...

# %%
len(df['track_id'].unique())
# Out:
# 81421

# %%
XO = []
for i,s in enumerate(df['artists']):
    if 'The Weeknd' in s:
        s = df.iloc[i]['track_name']
        XO.append(s)
pprint.pprint(set(XO))
# Out:
# {'After Hours',
#  'Blinding Lights',
#  'Call Out My Name',
#  'Die For You',
#  'Hawái - Remix',
#  'I Feel It Coming',
#  'I Was Never There',
#  'Lost in the Fire (feat. The Weeknd)',
#  'Love Me Harder',
#  'Make It (feat. The Weeknd) [DJAmg Remixer]',
#  'Moth To A Flame',
#  'Moth To A Flame (feat. The Weeknd) - Adriatique Remix',
#  'Moth To A Flame (with The Weeknd)',
#  'Moth To A Flame (with The Weeknd) - Extended Mix',
#  'Moth To A Flame (with The Weeknd, Moojo) - Moojo Remix',
#  'Odd Look',
#  'Or Nah (feat. The Weeknd, Wiz Khalifa & DJ Mustard) - Remix',
#  'Or Nah - Remix',
#  'Out of Time',
#  'Over Now (with The Weeknd)',
#  'Save Your Tears',
#  'Starboy',
#  'Take My Breath - Single Version',
#  'Tears In The Club (feat. The Weeknd)',
#  'The Hills',
#  'You Right',
#  'tears in the club',
#  'tears in the club (feat. the weeknd)'}

# %%
# df = df.reset_index(drop=True)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='str')

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# ...

# %%
df.drop(columns = {'popularity', 'duration_ms', 'album_name'}, inplace = True)

# %%
data = [ 'danceability',	'energy',	'key',	'loudness'	,'mode',	'speechiness'	,'acousticness',	'instrumentalness',	'liveness',	'valence',	'tempo',	'time_signature']

# %%
meta_data = df[data]

# %%
# meta_data = np.array(meta_data)

# %%
df.drop(columns = data ,inplace =True)

# %%
df.head()
# Out:
#                  track_id                 artists                  track_name  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino                      Comedy
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward            Ghost - Acoustic
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN              To Begin Again
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis  Can't Help Falling In Love
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet                     Hold On
#
#    explicit track_genre
# 0     False    acoustic
# 1     False    acoustic
# 2     False    acoustic
# 3     False    acoustic
# 4     False    acoustic

# %%
# df.rename(columns={'track_name':'song'},inplace = True)

# %%
for col in df.select_dtypes(include = ['str']).columns:
    if col == 'track_id':
        continue
    df[col] = df[col].str.strip().str.lower()

# %%
df.head()
# Out:
#                  track_id                 artists                  track_name  \
# 0  5SuOikwiRyPMVoIQDJUgSV             gen hoshino                      comedy
# 1  4qPNDBW1i3p13qLCt0Ki3A            ben woodward            ghost - acoustic
# 2  1iJBSr7s7jYXzM8EGcbK5b  ingrid michaelson;zayn              to begin again
# 3  6lfxq3CG4xtTiEg7opyCyx            kina grannis  can't help falling in love
# 4  5vjLSffimiIP26QG5WcN2K        chord overstreet                     hold on
#
#    explicit track_genre
# 0     False    acoustic
# 1     False    acoustic
# 2     False    acoustic
# 3     False    acoustic
# 4     False    acoustic

# %%
len(df['track_genre'].unique())
# Out:
# 113

# %%
df['artists']
# Out:
# 0                    gen hoshino
# 1                   ben woodward
# 2         ingrid michaelson;zayn
# 3                   kina grannis
# 4               chord overstreet
#                    ...
# 113995             rainy lullaby
# 113996             rainy lullaby
# 113997             cesária evora
# 113998          michael w. smith
# 113999             cesária evora
# Name: artists, Length: 81421, dtype: str

# %%
df['tags'] = df['artists']+ ' ' +df['track_genre']

# %%
df['artists'] = df['artists'].str.split(';')

# %%
df.head()
# Out:
#                  track_id                    artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV              [gen hoshino]
# 1  4qPNDBW1i3p13qLCt0Ki3A             [ben woodward]
# 2  1iJBSr7s7jYXzM8EGcbK5b  [ingrid michaelson, zayn]
# 3  6lfxq3CG4xtTiEg7opyCyx             [kina grannis]
# 4  5vjLSffimiIP26QG5WcN2K         [chord overstreet]
#
#                    track_name  explicit track_genre  \
# 0                      comedy     False    acoustic
# 1            ghost - acoustic     False    acoustic
# 2              to begin again     False    acoustic
# 3  can't help falling in love     False    acoustic
# 4                     hold on     False    acoustic
#
#                               tags
# 0             gen hoshino acoustic
# 1            ben woodward acoustic
# 2  ingrid michaelson;zayn acoustic
# 3            kina grannis acoustic
# 4        chord overstreet acoustic

# %%
df[df.duplicated(subset=[ 'track_name','tags','explicit'])]
# Out:
#                       track_id             artists                 track_name  \
# 70      16dkWKIlBsfYTISCVuDs0w          [ron pope]        a drop in the ocean
# 190     0v0pc1lIt5p6EBX7pnfOGF    [ross copperman]  holding on and letting go
# 876     2vP0JcTiuYnzrBy45ACKBz      [keisha white]         the weakness in me
# 1992    33dYPQCYUztZKUJqmyQR6L  [william onyeabor]       the moon and the sun
# 2161    5WTKiRTdoDk07YJOP7y8DU             [kaleo]             way down we go
# ...                        ...                 ...                        ...
# 111636  6yoqKyNAJOjTlFnDM8u6Ka      [boozoo bajou]          night over manaus
# 113574  0k3H456t5wd6kkje7MTarL  [hillsong worship]          shout to the lord
# 113649  7MzEigadl6tP6TmaxagWNt  [hillsong worship]         worthy is the lamb
# 113708  1jLAfwuB7v9lBdwDcJF39G      [phil wickham]          house of the lord
# 113946  5XTdgvMiVHNSzzFrKAXU91     [cesária evora]                 petit pays
#
# ...

# %%
df['tags']
# Out:
# 0                    gen hoshino acoustic
# 1                   ben woodward acoustic
# 2         ingrid michaelson;zayn acoustic
# 3                   kina grannis acoustic
# 4               chord overstreet acoustic
#                        ...
# 113995          rainy lullaby world-music
# 113996          rainy lullaby world-music
# 113997          cesária evora world-music
# 113998       michael w. smith world-music
# 113999          cesária evora world-music
# Name: tags, Length: 81421, dtype: str

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# https://huggingface.co/sentence-transformers

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 7757.75it/s]

# %%
# %%time
tag_embeddings = model.encode(df['tags'].tolist(), normalize_embeddings = True)
# Out:
# CPU times: user 16.8 s, sys: 3.23 s, total: 20.1 s
# Wall time: 10.8 s

# %%
tag_embeddings
# Out:
# array([[-0.08406793,  0.06625666, -0.00450069, ...,  0.01489832,
#         -0.01095574,  0.00164438],
#        [-0.0499217 , -0.02553014,  0.0193305 , ...,  0.003179  ,
#         -0.03412907, -0.03640854],
#        [-0.11297348, -0.04440821, -0.02443785, ..., -0.04375131,
#          0.05449506, -0.03858234],
#        ...,
#        [-0.000725  , -0.0265787 , -0.01766037, ..., -0.02808608,
#          0.0374263 , -0.04857159],
#        [-0.05028116,  0.01812024,  0.00465453, ...,  0.00109861,
#          0.01093575, -0.0654993 ],
#        [-0.000725  , -0.0265787 , -0.01766037, ..., -0.02808608,
#          0.0374263 , -0.04857159]], shape=(81421, 384), dtype=float32)

# %%
from sklearn.preprocessing import StandardScaler, normalize

# %%
sc = StandardScaler()

# %%
meta_data
# Out:
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0              0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 1              0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 2              0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 3              0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 4              0.618  0.4430    2    -9.681     1       0.0526        0.4690
# ...              ...     ...  ...       ...   ...          ...           ...
# 113995         0.172  0.2350    5   -16.393     1       0.0422        0.6400
# 113996         0.174  0.1170    0   -18.318     0       0.0401        0.9940
# 113997         0.629  0.3290    0   -10.895     0       0.0420        0.8670
# 113998         0.587  0.5060    7   -10.889     1       0.0297        0.3810
# 113999         0.526  0.4870    1   -10.204     0       0.0725        0.6810
#
# ...

# %%
audio_data = sc.fit_transform(meta_data)

# %%
audio_data = normalize (audio_data)

# %%
audio_data.shape, tag_embeddings.shape
# Out:
# ((81421, 12), (81421, 384))

# %%
merged = np.concatenate([audio_data, tag_embeddings], axis = 1)

# %%
merged = normalize(merged)

# %%
audio_data.max()
# Out:
# np.float64(0.953764520770774)

# %%
df.head()
# Out:
#                  track_id                    artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV              [gen hoshino]
# 1  4qPNDBW1i3p13qLCt0Ki3A             [ben woodward]
# 2  1iJBSr7s7jYXzM8EGcbK5b  [ingrid michaelson, zayn]
# 3  6lfxq3CG4xtTiEg7opyCyx             [kina grannis]
# 4  5vjLSffimiIP26QG5WcN2K         [chord overstreet]
#
#                    track_name  explicit track_genre  \
# 0                      comedy     False    acoustic
# 1            ghost - acoustic     False    acoustic
# 2              to begin again     False    acoustic
# 3  can't help falling in love     False    acoustic
# 4                     hold on     False    acoustic
#
#                               tags
# 0             gen hoshino acoustic
# 1            ben woodward acoustic
# 2  ingrid michaelson;zayn acoustic
# 3            kina grannis acoustic
# 4        chord overstreet acoustic

# %%
def score(song, all_song):
    return song @ all_song

# %%
df.shape
# Out:
# (81421, 6)

# %%
df.sample(5)
# Out:
#                      track_id                                    artists  \
# 14551  6RYmlLkbx5ZAbOjKDqXEzp  [wolfgang amadeus mozart, danielle laval]
# 46254  2tBO9sDqez1uQYsb8EYkjx                              [sabke morde]
# 45456  2PgaoRDmiqMMgqgTIfue4u                                    [kmfdm]
# 5765   3337Hpv6XBBEWLwoRsSMxT                                 [tersivel]
# 78062  6ssqfhhoK0uLambmUXMbIA                                [die atzen]
#
#                                               track_name  explicit  \
# 14551  8 variations on "laat ons juichen" by c.e. gra...     False
# 46254                                        seebe sorkh     False
# 45456                                   search & destroy     False
# 5765                              cruzat beer house song     False
# 78062                                       diss is nice      True
#
#        track_genre                                              tags
# ...

# %%
type(df['artists'].iloc[0])
# Out:
# list

# %%
merged.T.shape
# Out:
# (396, 81421)

# %%
ind = np.argsort(score(merged[81004].reshape(1,-1), merged.T).flatten())[-6:-1][::-1]
ind
# Out:
# array([80936, 81373, 80971, 81051, 80963])

# %%
df.iloc[81004]
# Out:
# track_id          6TyyGSk69X8S922AF5L4qE
# artists                  [shane & shane]
# track_name                  living water
# explicit                           False
# track_genre                  world-music
# tags           shane & shane world-music
# Name: 81004, dtype: object

# %%
for i in ind :
    print(df.iloc[i])
# Out:
# track_id          1SnZi2eVU2kcXRNJT6ek4J
# artists                  [shane & shane]
# track_name            how great thou art
# explicit                           False
# track_genre                  world-music
# tags           shane & shane world-music
# Name: 80936, dtype: object
# track_id          4JDmqxJrJS9FoMPzWmILkQ
# artists                  [shane & shane]
# track_name      psalm 34 (taste and see)
# explicit                           False
# track_genre                  world-music
# tags           shane & shane world-music
# Name: 81373, dtype: object
# track_id         7wBs0H1Ebr1h14Qqm43KiO
# artists                  [chris tomlin]
# track_name                   white flag
# explicit                          False
# track_genre                 world-music
# tags           chris tomlin world-music
# Name: 80971, dtype: object
# track_id         4Upx1mXplDCRQKpnF64KXc
# artists                  [chris tomlin]
# track_name               great forgiver
# ...

# %%
np.argsort(score(merged[20100].reshape(1,-1),merged.T).flatten())[::-1]
# Out:
# array([20100, 20046, 20241, ..., 58777, 26877, 58602], shape=(81421,))

# %%
import re

# %%
def get_similar_song(song_name = None, artist_name = None, Explicit = True):
    result = []
    track = song_name

    
    if  artist_name:
        artist_name = artist_name.lower().strip()
        artist_name = df['artists'].apply(lambda a : artist_name in a )
    else :
        artist_name = pd.Series(True, index=df.index)
        
    if song_name:
        song_name = song_name.lower().strip()
        song_name = df['track_name'].str.contains(rf"\b{re.escape(song_name.strip())}\b",regex=True)
    else:
        song_name = pd.Series(True, index=df.index)
        
    # Indexing and song extraction 
    res = song_name & artist_name 
        
    if not res.any():
        return "No matching song found."
    
    if not track:
        query_mat = merged[res].mean(axis=0)
    else:
        song_ind = df[res].index[0]
        query_mat = merged[song_ind]
    
    score = np.argsort(query_mat.reshape(1,-1)@ merged.T).flatten()[::-1]
    
    for i in score:
        if not Explicit :
            if df.iloc[i]['explicit']:
                continue
        sng = df.iloc[i]['track_name']
        if sng == track: # skipping the querry song
            continue
        
        art = df.iloc[i]['artists'] 
        link = df.iloc[i]['track_id']
        if ((sng,art)) not in result:
            result.append((link, sng, art))
        if len(result)==10:
            break
    
    result =  [result[i] for i in (np.random.choice(10, replace = False, size= 5 ))]
    result = pd.DataFrame(result, columns = ['Link', "Song", "Artist(s)"])
    return result

# %%
get_similar_song()
# Out:
#                      Link                     Song  \
# 0  7pqp5R4GY8HTaAbpAGZJFb                   彼女はブルー
# 1  3SatS51LrCRNkQN1quaB7W                si me ves
# 2  3qwQ3PEudWSXRaWbsJUUx5  stay - jonas blue remix
# 3  1xVviGd6Y0zujEmjiTzdiL             fruta amarga
# 4  0kuL28JVeWVO86sXrCYFar            los cangrejos
#
#                           Artist(s)
# 0                    [shogo hamada]
# 1                 [cadena perpetua]
# 2  [zedd, alessia cara, jonas blue]
# 3                  [karamelo santo]
# 4                  [karamelo santo]

# %%
get_similar_song(artist_name='the weeknd')
# Out:
#                      Link                               Song  \
# 0  0MnmtOOke4uQVBMAjIgwVZ                        after hours
# 1  0VO8gYVDSwM1Qdd2GsMoYK  moth to a flame (with the weeknd)
# 2  2Ch7LmS7r2Gy2kc64wv3Bz                        die for you
# 3  5XCa3ygRyz2R9avSi0CYJI                   i feel it coming
# 4  0VjIjW4GlUZAMYd2vXMi3b                    blinding lights
#
#                            Artist(s)
# 0                       [the weeknd]
# 1  [swedish house mafia, the weeknd]
# 2                       [the weeknd]
# 3            [the weeknd, daft punk]
# 4                       [the weeknd]

# %%
df[df['track_name']=='the hills']
# Out:
#                      track_id       artists track_name  explicit track_genre  \
# 14859  7yF0tjZPXO9x4v0M9U6VQy       [kloud]  the hills     False        club
# 61331  4g7118rCobKcU4XQXSFlBS  [the weeknd]  the hills      True         pop
#
#                  tags
# 14859      kloud club
# 61331  the weeknd pop

# %%
import joblib
np.save('merged_mat.npy',merged)
joblib.dump(df,'df.pkl')
# Out:
# ['df.pkl']

# %%
s='  '
s.strip()
# Out:
# ''
